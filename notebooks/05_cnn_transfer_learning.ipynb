# %% [markdown]
# # 05 — CNN Transfer Learning
#
# Fine-tune EfficientNet-B0 and ResNet-50 on the fashion dataset.

# %%
import sys; sys.path.insert(0, '..')
from src.models.cnn import build_efficientnet_b0, build_resnet50, freeze_backbone, unfreeze_all
from src.train import train_model
from src.evaluate import compute_metrics, plot_confusion_matrix
from src.augmentation import get_train_transform, get_val_transform
from src.data_utils import CLASSES, SEED
import torch, pandas as pd

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using device:', DEVICE)

# %% [markdown]
# ## Dataset

# %%
# from torchvision.datasets import ImageFolder
# from torch.utils.data import DataLoader, WeightedRandomSampler
# train_ds = ImageFolder('../data/processed/train', transform=get_train_transform())
# val_ds   = ImageFolder('../data/processed/val',   transform=get_val_transform())
# train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=2)
# val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False, num_workers=2)

# %% [markdown]
# ## EfficientNet-B0 — Phase 1 (freeze backbone)

# %%
# model = build_efficientnet_b0(pretrained=True).to(DEVICE)
# freeze_backbone(model)
# optimizer = torch.optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)
# criterion = torch.nn.CrossEntropyLoss()
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5)
# history_p1 = train_model(model, train_loader, val_loader, optimizer, criterion,
#                          scheduler, num_epochs=5, patience=3, device=DEVICE,
#                          checkpoint_path='../outputs/models/effnet_b0_phase1.pth')

# %% [markdown]
# ## EfficientNet-B0 — Phase 2 (unfreeze all)

# %%
# unfreeze_all(model)
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-2)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)
# history_p2 = train_model(model, train_loader, val_loader, optimizer, criterion,
#                          scheduler, num_epochs=15, patience=5, device=DEVICE,
#                          checkpoint_path='../outputs/models/effnet_b0_best.pth')

# %% [markdown]
# ## ResNet-50  *(same two-phase pattern)*

# %% [markdown]
# ## Results
# Log final val metrics to MLflow and save confusion matrices.
