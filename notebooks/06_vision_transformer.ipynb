# %% [markdown]
# # 06 — Vision Transformer
#
# Fine-tune ViT-B/16 and Swin-T on the fashion dataset.

# %%
import sys; sys.path.insert(0, '..')
from src.models.vit import build_vit_b16, build_swin_tiny
from src.train import train_model
from src.evaluate import compute_metrics, plot_confusion_matrix
from src.augmentation import get_train_transform, get_val_transform
import torch

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using device:', DEVICE)

# %% [markdown]
# ## Swin-T (recommended for limited GPU memory)

# %%
# model = build_swin_tiny(pretrained=True).to(DEVICE)
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-2)
# criterion = torch.nn.CrossEntropyLoss()
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20)
# history = train_model(model, train_loader, val_loader, optimizer, criterion,
#                       scheduler, num_epochs=20, patience=5, device=DEVICE,
#                       checkpoint_path='../outputs/models/swin_tiny_best.pth')

# %% [markdown]
# ## ViT-B/16 (larger model — may require gradient accumulation or mixed precision)

# %%
# model = build_vit_b16(pretrained=True).to(DEVICE)
# history = train_model(model, train_loader, val_loader, optimizer, criterion,
#                       scheduler, num_epochs=20, patience=5, device=DEVICE,
#                       use_amp=True,
#                       checkpoint_path='../outputs/models/vit_b16_best.pth')

# %% [markdown]
# ## Results
# Compare Swin-T vs. ViT-B/16; log to MLflow.
